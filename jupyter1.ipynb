# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import Tracker
import time

model = YOLO('yolov8s.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('traffic1.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

count = 0
tracker = Tracker()
vh_down = {}
counter = []
vh_up = {}
counter1 = []
vh_dtime = {}
vh_utime = {}
cy1 = 322
cy2 = 368
offset = 6

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (1020, 500))

def display_speed(frame, cx, cy, vehicle_id, counter_list, elapsed_time, x, y):
    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
    cv2.putText(frame, str(vehicle_id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    if vehicle_id not in counter_list:
        counter_list.append(vehicle_id)

    distance = 10

    if elapsed_time > 0:
        speed_ms = distance / elapsed_time
        speed_km = speed_ms * 3.6
        cv2.putText(frame, str(int(speed_km)) + ' Km/h', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)
    else:
        cv2.putText(frame, 'Speed N/A', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    count += 1
    if count % 3 != 0:
        continue

    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")

    list = []

    for index, row in px.iterrows():
        x1, y1, x2, y2, _, d = map(int, row)
        c = class_list[d]

        if c in ['car', 'truck', 'bus']:
            list.append([x1, y1, x2, y2])

    bbox_id = tracker.update(list)

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = (x3 + x4) // 2
        cy = (y3 + y4) // 2

        if cy1 - offset < cy < cy1 + offset:
            vh_down[id] = cy
            vh_dtime[id] = time.time()

        if cy2 - offset < cy < cy2 + offset:
            vh_up[id] = cy
            vh_utime[id] = time.time()

        cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 1)
        if id in vh_down:
            elapsed_time = time.time() - vh_dtime[id]
            display_speed(frame, cx, cy, id, counter, elapsed_time, x4, y4)
        if id in vh_up:
            elapsed_time2 = time.time() - vh_utime[id]
            display_speed(frame, cx, cy, id, counter1, elapsed_time2, x4, y4)

    cv2.line(frame, (267, cy1), (829, cy1), (255, 255, 255), 1)
    cv2.putText(frame, '1line', (274, 318), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    cv2.line(frame, (167, cy2), (932, cy2), (255, 255, 255), 1)
    cv2.putText(frame, '2line', (181, 363), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    cv2.putText(frame, 'GoingDown: ' + str(len(counter)), (60, 40), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)
    cv2.putText(frame, 'GoingUp: ' + str(len(counter1)), (60, 130), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)

    out.write(frame)

    cv2.imshow("RGB", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 3 cars, 276.9ms
# Speed: 16.9ms preprocess, 276.9ms inference, 2720.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 273.6ms
# Speed: 3.5ms preprocess, 273.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 211.5ms
# Speed: 0.0ms preprocess, 211.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 238.5ms
# Speed: 0.0ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 236.9ms
# Speed: 0.0ms preprocess, 236.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 227.5ms
# Speed: 0.0ms preprocess, 227.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# [628, 87]
#
# 0: 320x640 4 cars, 1 truck, 220.8ms
# Speed: 3.2ms preprocess, 220.8ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 241.4ms
# Speed: 0.0ms preprocess, 241.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 227.8ms
# Speed: 0.0ms preprocess, 227.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 267.9ms
# Speed: 5.1ms preprocess, 267.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 248.3ms
# Speed: 1.5ms preprocess, 248.3ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 226.7ms
# Speed: 0.0ms preprocess, 226.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 194.8ms
# Speed: 1.4ms preprocess, 194.8ms inference, 14.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars,
ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 246.5ms
# Speed: 1.5ms preprocess, 246.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 237.9ms
# Speed: 4.9ms preprocess, 237.9ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 248.1ms
# Speed: 0.0ms preprocess, 248.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 247.7ms
# Speed: 0.9ms preprocess, 247.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 235.7ms
# Speed: 5.6ms preprocess, 235.7ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 234.1ms
# Speed: 3.8ms preprocess, 234.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 222.7ms
# Speed: 0.9ms preprocess, 222.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 230.3ms
# Speed: 4.3ms preprocess, 230.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 263.3ms
# Speed: 0.0ms preprocess, 263.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 260.6ms
# Speed: 4.4ms preprocess, 260.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 264.2ms
# Speed: 0.7ms preprocess, 264.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 258.2ms
# Speed: 0.0ms preprocess, 258.2ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 204.9ms
# Speed: 10.6ms preprocess, 204.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 251.3ms
# Speed: 0.0ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 274.7ms
# Speed: 0.0ms preprocess, 274.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 271.9ms
# Speed: 4.8ms preprocess, 271.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 265.3ms
# Speed: 6.2ms preprocess, 265.3ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 257.0ms
# Speed: 3.4ms preprocess, 257.0ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 264.9ms
# Speed: 0.5ms preprocess, 264.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 244.6ms
# Speed: 3.7ms preprocess, 244.6ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 234.2ms
# Speed: 0.0ms preprocess, 234.2ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 247.8ms
# Speed: 0.0ms preprocess, 247.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 266.3ms
# Speed: 0.0ms preprocess, 266.3ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 243.3ms
# Speed: 7.4ms preprocess, 243.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 252.9ms
# Speed: 4.4ms preprocess, 252.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 212.8ms
# Speed: 3.0ms preprocess, 212.8ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 228.6ms
# Speed: 0.0ms preprocess, 228.6ms inference, 7.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 222.1ms
# Speed: 5.6ms preprocess, 222.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 265.7ms
# Speed: 5.0ms preprocess, 265.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 3 trucks, 262.7ms
# Speed: 0.0ms preprocess, 262.7ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
# [302, 40]
#
# 0: 320x640 9 cars, 3 trucks, 262.6ms
# Speed: 5.5ms preprocess, 262.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 254.7ms
# Speed: 2.5ms preprocess, 254.7ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 294.9ms
# Speed: 2.6ms preprocess, 294.9ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 284.3ms
# Speed: 5.7ms preprocess, 284.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 255.4ms
# Speed: 1.6ms preprocess, 255.4ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 279.2ms
# Speed: 0.0ms preprocess, 279.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 247.6ms
# Speed: 2.0ms preprocess, 247.6ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 243.1ms
# Speed: 1.9ms preprocess, 243.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 249.5ms
# Speed: 0.0ms preprocess, 249.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 247.7ms
# Speed: 1.5ms preprocess, 247.7ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 277.0ms
# Speed: 0.0ms preprocess, 277.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 287.5ms
# Speed: 4.2ms preprocess, 287.5ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 264.5ms
# Speed: 0.0ms preprocess, 264.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 243.4ms
# Speed: 3.3ms preprocess, 243.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 241.4ms
# Speed: 2.1ms preprocess, 241.4ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 242.7ms
# Speed: 5.3ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 236.5ms
# Speed: 6.5ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 237.6ms
# Speed: 4.0ms preprocess, 237.6ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 233.9ms
# Speed: 0.0ms preprocess, 233.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 286.3ms
# Speed: 0.0ms preprocess, 286.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 249.1ms
# Speed: 0.5ms preprocess, 249.1ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 249.6ms
# Speed: 0.0ms preprocess, 249.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 243.4ms
# Speed: 2.1ms preprocess, 243.4ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 243.7ms
# Speed: 0.0ms preprocess, 243.7ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 225.4ms
# Speed: 3.1ms preprocess, 225.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 230.7ms
# Speed: 4.2ms preprocess, 230.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 256.1ms
# Speed: 0.0ms preprocess, 256.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 251.0ms
# Speed: 0.0ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 264.1ms
# Speed: 7.8ms preprocess, 264.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 258.6ms
# Speed: 6.8ms preprocess, 258.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 277.7ms
# Speed: 0.0ms preprocess, 277.7ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 1 train, 2 trucks, 261.4ms
# Speed: 0.0ms preprocess, 261.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 246.8ms
# Speed: 2.9ms preprocess, 246.8ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 227.6ms
# Speed: 6.7ms preprocess, 227.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 242.5ms
# Speed: 3.4ms preprocess, 242.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 227.6ms
# Speed: 0.0ms preprocess, 227.6ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 229.7ms
# Speed: 7.7ms preprocess, 229.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 221.7ms
# Speed: 0.0ms preprocess, 221.7ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 222.8ms
# Speed: 4.7ms preprocess, 222.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 235.7ms
# Speed: 7.7ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 trucks, 181.1ms
# Speed: 4.9ms preprocess, 181.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 206.3ms
# Speed: 0.0ms preprocess, 206.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 3 trucks, 202.1ms
# Speed: 0.0ms preprocess, 202.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 205.0ms
# Speed: 4.5ms preprocess, 205.0ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 234.3ms
# Speed: 0.0ms preprocess, 234.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 235.2ms
# Speed: 3.0ms preprocess, 235.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 254.5ms
# Speed: 0.0ms preprocess, 254.5ms inference, 7.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 238.2ms
# Speed: 4.1ms preprocess, 238.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 247.0ms
# Speed: 0.0ms preprocess, 247.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 243.2ms
# Speed: 0.0ms preprocess, 243.2ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 217.5ms
# Speed: 3.4ms preprocess, 217.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 237.5ms
# Speed: 4.3ms preprocess, 237.5ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 284.6ms
# Speed: 5.5ms preprocess, 284.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 232.8ms
# Speed: 2.5ms preprocess, 232.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 223.2ms
# Speed: 0.0ms preprocess, 223.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 194.9ms
# Speed: 1.3ms preprocess, 194.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 249.8ms
# Speed: 4.4ms preprocess, 249.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 259.0ms
# Speed: 10.3ms preprocess, 259.0ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 237.3ms
# Speed: 4.8ms preprocess, 237.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 233.5ms
# Speed: 2.7ms preprocess, 233.5ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 242.3ms
# Speed: 0.0ms preprocess, 242.3ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 257.5ms
# Speed: 5.9ms preprocess, 257.5ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 275.6ms
# Speed: 0.0ms preprocess, 275.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 243.7ms
# Speed: 4.4ms preprocess, 243.7ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 247.5ms
# Speed: 5.1ms preprocess, 247.5ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 256.1ms
# Speed: 6.1ms preprocess, 256.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 2 trucks, 250.4ms
# Speed: 2.5ms preprocess, 250.4ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 trucks, 201.7ms
# Speed: 0.0ms preprocess, 201.7ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 bus, 3 trucks, 213.0ms
# Speed: 4.5ms preprocess, 213.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 bus, 4 trucks, 233.1ms
# Speed: 3.5ms preprocess, 233.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 269.3ms
# Speed: 0.0ms preprocess, 269.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 bus, 1 truck, 246.4ms
# Speed: 0.0ms preprocess, 246.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 bus, 2 trucks, 245.4ms
# Speed: 5.7ms preprocess, 245.4ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 290.4ms
# Speed: 7.8ms preprocess, 290.4ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
